# %%
import pandas as pd

# %%
df5 = pd.read_csv('data/all_data/201808-citibike-tripdata.csv')
df6 = pd.read_csv('data/all_data/201807-citibike-tripdata.csv')
df7 = pd.read_csv('data/all_data/201806-citibike-tripdata.csv')
df8 = pd.read_csv('data/all_data/201805-citibike-tripdata.csv')
df9 = pd.read_csv('data/all_data/201804-citibike-tripdata.csv')
df10 = pd.read_csv('data/all_data/201803-citibike-tripdata.csv')
df11 = pd.read_csv('data/all_data/201802-citibike-tripdata.csv')
df12 = pd.read_csv('data/all_data/201801-citibike-tripdata.csv')
df13 = pd.read_csv('data/all_data/201712-citibike-tripdata.csv')

# %%
list(df1.columns.values)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
df2018= pd.concat([df5, df6, df7, df8, df9, df10, df11, df12, df13])

# %%
df1
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 689  2018-12-01 00:00:04.3020  2018-12-01 00:11:33.8460
# 1                 204  2018-12-01 00:00:05.5330  2018-12-01 00:03:30.5230
# 2                 316  2018-12-01 00:00:10.2330  2018-12-01 00:05:27.2030
# 3                 726  2018-12-01 00:00:21.9570  2018-12-01 00:12:28.1830
# 4                 397  2018-12-01 00:00:29.6320  2018-12-01 00:07:07.4460
# 5                 299  2018-12-01 00:00:30.8650  2018-12-01 00:05:30.6360
# 6                 414  2018-12-01 00:00:34.6870  2018-12-01 00:07:29.3410
# 7                 216  2018-12-01 00:00:39.9290  2018-12-01 00:04:16.7290
# 8               43287  2018-12-01 00:00:49.8680  2018-12-01 12:02:16.9530
# 9                 363  2018-12-01 00:00:57.8070  2018-12-01 00:07:01.0760
# 10                807  2018-12-01 00:01:06.1340  2018-12-01 00:14:33.5390
# 11                266  2018-12-01 00:00:55.6870  2018-12-01 00:05:22.1040
# ...

# %%
df2018.to_csv('citibike-tripdata.csv')

# %%
df2018.count()
# Out:
# tripduration               12404905
# starttime                  12404905
# stoptime                   12404905
# start station id           12403517
# start station name         12403517
# start station latitude     12404905
# start station longitude    12404905
# end station id             12403517
# end station name           12403517
# end station latitude       12404905
# end station longitude      12404905
# bikeid                     12404905
# usertype                   12404905
# birth year                 12365460
# gender                     12404905
# dtype: int64
